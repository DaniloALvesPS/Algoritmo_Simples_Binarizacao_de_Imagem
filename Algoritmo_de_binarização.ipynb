# %% [markdown]
# <a href="https://colab.research.google.com/github/DaniloALvesPS/Algoritmo_Simples_Binarizacao_de_Imagem/blob/main/Algoritmo_de_binariza%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

# Carrega a imagem em cores
img_color = cv2.imread('Outras-pessoas.jpg')

# Converte a imagem para escala de cinza
img_gray = cv2.cvtColor(img_color, cv2.COLOR_BGR2GRAY)

# Binariza a imagem com threshold = 127
ret, img_bin = cv2.threshold(img_gray, 127, 255, cv2.THRESH_BINARY)

# Mostra as imagens
cv2_imshow(img_gray)
cv2_imshow(img_bin)
cv2_imshow(img_color)
# Out:
# <PIL.Image.Image image mode=L size=1000x480 at 0x7F9D575989A0>
# <PIL.Image.Image image mode=L size=1000x480 at 0x7F9D57598640>
# <PIL.Image.Image image mode=RGB size=1000x480 at 0x7F9D84105280>
